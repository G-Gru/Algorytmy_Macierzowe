# %% [markdown]
# A file for example usages of matrix determinant algorithm.

# %%
include(joinpath(@__DIR__, "..", "src", "matrix_det.jl"))

using .matrix_det

A3 = [4.0 3.0 2.0; 2.0 1.0 5.0; 6.0 7.0 8.0]
det3 = lu_det(A3)
# Out:
# -50.0
